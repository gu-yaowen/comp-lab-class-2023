# %%
import numpy as np
import mdtraj as md
from matplotlib import pyplot as plt

# %%
meta_grid = np.loadtxt('../Inputs/dialaA/ex1_metad_COLVAR_A_bf1',
                       comments='#')
time = meta_grid[:, 0]
time = time[time < 2000]
phi = meta_grid[:, 1]
phi = phi[:len(time)]
# plot time < 2ns the change of phi
plt.figure()
plt.scatter(time, phi, alpha=0.5, s=10)
plt.title('Time evolution of the metadynamics CV during the \n'
          'first 2 ns of a metadynamics simulation of alanine dipeptide in vacuum')
plt.ylabel('phi dihedral')
plt.xlabel('Time (ps)')
plt.savefig('../Figures/Lugano_ex3_phi-time_2ns_A_biasfactor1.png')

# %%
meta_grid = np.loadtxt('../Inputs/dialaA/ex1_metad_COLVAR_A_bf2',
                       comments='#')
time = meta_grid[:, 0]
time = time[time < 2000]
phi = meta_grid[:, 1]
phi = phi[:len(time)]
# plot time < 2ns the change of phi
plt.figure()
plt.scatter(time, phi, alpha=0.5, s=10)
plt.title('Time evolution of the metadynamics CV during the \n'
          'first 2 ns of a metadynamics simulation of alanine dipeptide in vacuum')
plt.ylabel('phi dihedral')
plt.xlabel('Time (ps)')
plt.savefig('../Figures/Lugano_ex3_phi-time_2ns_A_biasfactor2.png')

# %%
meta_grid = np.loadtxt('../Inputs/dialaA/ex1_metad_COLVAR_A_bf5',
                       comments='#')
time = meta_grid[:, 0]
time = time[time < 2000]
phi = meta_grid[:, 1]
phi = phi[:len(time)]
# plot time < 2ns the change of phi
plt.figure()
plt.scatter(time, phi, alpha=0.5, s=10)
plt.title('Time evolution of the metadynamics CV during the \n'
          'first 2 ns of a metadynamics simulation of alanine dipeptide in vacuum')
plt.ylabel('phi dihedral')
plt.xlabel('Time (ps)')
plt.savefig('../Figures/Lugano_ex3_phi-time_2ns_A_biasfactor5.png')

# %%
meta_grid = np.loadtxt('../Inputs/dialaA/ex1_metad_COLVAR_A_bf15',
                       comments='#')
time = meta_grid[:, 0]
time = time[time < 2000]
phi = meta_grid[:, 1]
phi = phi[:len(time)]
# plot time < 2ns the change of phi
plt.figure()
plt.scatter(time, phi, alpha=0.5, s=10)
plt.title('Time evolution of the metadynamics CV during the \n'
          'first 2 ns of a metadynamics simulation of alanine dipeptide in vacuum')
plt.ylabel('phi dihedral')
plt.xlabel('Time (ps)')
plt.savefig('../Figures/Lugano_ex3_phi-time_2ns_A_biasfactor15.png')

# %%
meta_hill = np.loadtxt('../Inputs/dialaA/metad_hill_A_all_biasf1.dat', comments='#')
plt.plot(meta_hill[:,0], meta_hill[:,1], alpha=0.5, label='bias factor=1')

meta_hill = np.loadtxt('../Inputs/dialaA/metad_hill_A_all_biasf2.dat', comments='#')
plt.plot(meta_hill[:,0], meta_hill[:,1], alpha=0.5, label='bias factor=2')

meta_hill = np.loadtxt('../Inputs/dialaA/metad_hill_A_all_biasf5.dat', comments='#')
plt.plot(meta_hill[:,0], meta_hill[:,1], alpha=0.5, label='bias factor=5')

meta_hill = np.loadtxt('../Inputs/dialaA/metad_hill_A_all.dat', comments='#')
plt.plot(meta_hill[:,0], meta_hill[:,1], alpha=0.5, label='bias factor=10(origin)', linewidth=3)

meta_hill = np.loadtxt('../Inputs/dialaA/metad_hill_A_all_biasf15.dat', comments='#')
plt.plot(meta_hill[:,0], meta_hill[:,1], alpha=0.5, label='bias factor=15')

plt.xlabel('phi dihedral')
plt.ylabel('free energy (kcal/mol)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Estimate of the free energy as a function of the dihedral \n'
          'phi from a 10ns-long well-tempered metadynamics simulation.')
plt.savefig('../Figures/Lugano_ex3_phi-FE_change_biasfactor_A.png', bbox_inches='tight', dpi=300)
